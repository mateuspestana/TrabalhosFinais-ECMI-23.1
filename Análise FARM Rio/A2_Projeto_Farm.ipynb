# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_parquet('dados_farm.parquet')
df['Account'] = df['Account'].str.lstrip(' ')
df['Post Created Date'] = pd.to_datetime(df['Post Created Date'])
df['Total Interactions'] = df['Total Interactions'].apply(lambda x: int(x.replace(',', '')))
df
# Out:
#                                            Account         User Name  \
# 0     Brechó & Bazar | Cacarecos da Gabis | Farm 🌸  cacarecosdagabis
# 1     Brechó & Bazar | Cacarecos da Gabis | Farm 🌸  cacarecosdagabis
# 2     Brechó & Bazar | Cacarecos da Gabis | Farm 🌸  cacarecosdagabis
# 3                       🌸 Cód. De vendedora C559 🌸     farmetequesou
# 4                     O seu provador da FARM aqui!    jupolidoindica
# ...                                            ...               ...
# 7974                                      FARM Rio         adorofarm
# 7975                                      FARM Rio         adorofarm
# 7976                                      FARM Rio         adorofarm
# 7977                                      FARM Rio         adorofarm
# 7978                                      FARM Rio         adorofarm
#
#       Followers at Posting             Post Created Post Created Date  \
# ...

# %%
df.tail()
# Out:
#        Account  User Name  Followers at Posting             Post Created  \
# 7974  FARM Rio  adorofarm              874408.0  2018-05-21 14:17:11 BRT
# 7975  FARM Rio  adorofarm              873276.0  2018-05-20 20:05:23 BRT
# 7976  FARM Rio  adorofarm              872748.0  2018-05-19 15:27:36 BRT
# 7977  FARM Rio  adorofarm              871995.0  2018-05-18 18:11:21 BRT
# 7978  FARM Rio  adorofarm              871995.0  2018-05-18 15:36:26 BRT
#
#      Post Created Date Post Created Time   Type  Total Interactions  Likes  \
# 7974        2018-05-21          14:17:11  Photo               13353  13036
# 7975        2018-05-20          20:05:23  Album                7992   7755
# 7976        2018-05-19          15:27:36  Video                3006   2833
# 7977        2018-05-18          18:11:21  Video                1530   1492
# 7978        2018-05-18          15:36:26  Video                1728   1659
#
#       Comments  ...  Like and View Counts Disabled  \
# ...

# %%
df.head(7979)
# Out:
#                                            Account         User Name  \
# 0     Brechó & Bazar | Cacarecos da Gabis | Farm 🌸  cacarecosdagabis
# 1     Brechó & Bazar | Cacarecos da Gabis | Farm 🌸  cacarecosdagabis
# 2     Brechó & Bazar | Cacarecos da Gabis | Farm 🌸  cacarecosdagabis
# 3                       🌸 Cód. De vendedora C559 🌸     farmetequesou
# 4                     O seu provador da FARM aqui!    jupolidoindica
# ...                                            ...               ...
# 7974                                      FARM Rio         adorofarm
# 7975                                      FARM Rio         adorofarm
# 7976                                      FARM Rio         adorofarm
# 7977                                      FARM Rio         adorofarm
# 7978                                      FARM Rio         adorofarm
#
#       Followers at Posting             Post Created Post Created Date  \
# ...

# %%
df_adorofarm = df[df['User Name']=="adorofarm"]

# %%
df_adorofarm['Total Interactions'].max()
# Out:
# 57464

# %%
df_adorofarm_mais2019 = df_adorofarm[df_adorofarm['Post Created Date'] >= '2019-12-31']

# %%
df_adorofarm_mais2019 = df[df['User Name'] == 'adorofarm'].query('`Post Created Date` >= "2019-01-01" and `Post Created Date` <= "2023-05-01"')
df_adorofarm_mais2019_interactions = df_adorofarm_mais2019.groupby('Post Created Date')['Total Interactions'].sum().reset_index()
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_adorofarm_mais2019_interactions, x='Post Created Date', y='Total Interactions').set(title='Total de interações - adorofarm')
# Out:
# [Text(0.5, 1.0, 'Total de interações - adorofarm')]

# %%
df[df['User Name']== 'adorofarm'].sort_values(by=['Total Interactions'], ascending=False)
# Out:
#        Account  User Name  Followers at Posting              Post Created  \
# 2768  FARM Rio  adorofarm             1557126.0   2021-06-09 12:36:42 BRT
# 4631  FARM Rio  adorofarm             1284563.0   2020-04-17 10:17:28 BRT
# 916   FARM Rio  adorofarm             1830872.0   2022-09-21 21:23:29 BRT
# 2335  FARM Rio  adorofarm             1588972.0   2021-09-20 14:55:30 BRT
# 7680  FARM Rio  adorofarm              914874.0   2018-07-24 19:58:53 BRT
# ...        ...        ...                   ...                       ...
# 6887  FARM Rio  adorofarm             1109452.0  2019-01-29 17:30:19 BRST
# 5952  FARM Rio  adorofarm             1108676.0   2019-07-24 20:31:34 BRT
# 5053  FARM Rio  adorofarm             1254584.0   2020-02-21 14:13:36 BRT
# 6886  FARM Rio  adorofarm             1109452.0  2019-01-29 17:31:53 BRST
# 6508  FARM Rio  adorofarm             1119008.0   2019-04-11 19:37:51 BRT
#
#      Post Created Date Post Created Time   Type  Total Interactions  Likes  \
# ...

# %%
df_adorofarm.dtypes
# Out:
# Account                                                              object
# User Name                                                            object
# Followers at Posting                                                float64
# Post Created                                                         object
# Post Created Date                                            datetime64[ns]
# Post Created Time                                                    object
# Type                                                                 object
# Total Interactions                                                    int64
# Likes                                                                 int64
# Comments                                                              int64
# Views                                                                 int64
# Like and View Counts Disabled                                          bool
# ...

# %%
df_adorofarm['Post Created Date'] = df_adorofarm['Post Created Date'].apply(lambda x: pd.to_datetime(x))
# Out:
# <ipython-input-11-6c01abf033a9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_adorofarm['Post Created Date'] = df_adorofarm['Post Created Date'].apply(lambda x: pd.to_datetime(x))

# %%
df_adorofarm_2019 = df[df['User Name'] == 'adorofarm'].query('`Post Created Date` >= "2019-01-01" and `Post Created Date` <= "2019-12-31"')
df_adorofarm_2019_interactions = df_adorofarm_2019.groupby('Post Created Date')['Total Interactions'].sum().reset_index()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_adorofarm_2019_interactions, x='Post Created Date', y='Total Interactions').set(title='Total de interações por dia 2019 - adorofarm')
# Out:
# [Text(0.5, 1.0, 'Total de interações por dia 2019 - adorofarm')]

# %%
df_adorofarm_2020 = df[df['User Name'] == 'adorofarm'].query('`Post Created Date` >= "2020-01-01" and `Post Created Date` <= "2020-12-31"')
df_adorofarm_2020_interactions = df_adorofarm_2020.groupby('Post Created Date')['Total Interactions'].sum().reset_index()
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_adorofarm_2020_interactions, x='Post Created Date', y='Total Interactions').set(title='Total de interações por dia 2020 - adorofarm')
# Out:
# [Text(0.5, 1.0, 'Total de interações por dia 2020 - adorofarm')]

# %%
df_adorofarm_2021 = df[df['User Name'] == 'adorofarm'].query('`Post Created Date` >= "2021-01-01" and `Post Created Date` <= "2021-12-31"')
df_adorofarm_2021_interactions = df_adorofarm_2021.groupby('Post Created Date')['Total Interactions'].sum().reset_index()
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_adorofarm_2021_interactions, x='Post Created Date', y='Total Interactions').set(title='Total de interações por dia 2021 - adorofarm')
# Out:
# [Text(0.5, 1.0, 'Total de interações por dia 2021 - adorofarm')]

# %%
df_adorofarm_2022 = df[df['User Name'] == 'adorofarm'].query('`Post Created Date` >= "2022-01-01" and `Post Created Date` <= "2022-12-31"')
df_adorofarm_2022_interactions = df_adorofarm_2022.groupby('Post Created Date')['Total Interactions'].sum().reset_index()
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_adorofarm_2022_interactions, x='Post Created Date', y='Total Interactions').set(title='Total de interações por dia 2022 - adorofarm')
# Out:
# [Text(0.5, 1.0, 'Total de interações por dia 2022 - adorofarm')]

# %%
df_farmrio = df[df['User Name']=="farmrio"]

# %%
df_farmrio['Total Interactions'].max()
# Out:
# 26744

# %%
df[df['User Name']== 'farmrio'].sort_values(by=['Total Interactions'], ascending=False)
# Out:
#        Account User Name  Followers at Posting             Post Created  \
# 757   FARM Rio   farmrio              698160.0  2022-11-16 16:38:42 BRT
# 3798  FARM Rio   farmrio              194845.0  2020-08-31 20:25:49 BRT
# 2349  FARM Rio   farmrio              423246.0  2021-09-16 19:19:10 BRT
# 1158  FARM Rio   farmrio              621005.0  2022-07-06 20:00:48 BRT
# 917   FARM Rio   farmrio              674666.0  2022-09-21 20:14:30 BRT
# ...        ...       ...                   ...                      ...
# 6199  FARM Rio   farmrio               64855.0  2019-06-16 18:36:32 BRT
# 5581  FARM Rio   farmrio               77740.0  2019-10-17 10:36:35 BRT
# 7532  FARM Rio   farmrio               62281.0  2018-08-23 17:55:00 BRT
# 6300  FARM Rio   farmrio               64855.0  2019-05-29 11:29:50 BRT
# 6128  FARM Rio   farmrio               64855.0  2019-06-28 11:10:00 BRT
#
#      Post Created Date Post Created Time   Type  Total Interactions  Likes  \
# ...

# %%
df_farmrio_mais2019 = df_farmrio[df_farmrio['Post Created Date'] >= '2019-12-31']

# %%
df_farmrio_mais2019 = df[df['User Name'] == 'farmrio'].query('`Post Created Date` >= "2019-01-01" and `Post Created Date` <= "2023-05-01"')
df_farmrio_mais2019_interactions = df_farmrio_mais2019.groupby('Post Created Date')['Total Interactions'].sum().reset_index()
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_farmrio_mais2019_interactions, x='Post Created Date', y='Total Interactions').set(title='Total de interações - farmrio')
# Out:
# [Text(0.5, 1.0, 'Total de interações - farmrio')]

# %%
df_farmrio.dtypes
# Out:
# Account                                                              object
# User Name                                                            object
# Followers at Posting                                                float64
# Post Created                                                         object
# Post Created Date                                            datetime64[ns]
# Post Created Time                                                    object
# Type                                                                 object
# Total Interactions                                                    int64
# Likes                                                                 int64
# Comments                                                              int64
# Views                                                                 int64
# Like and View Counts Disabled                                          bool
# ...

# %%
df_farmrio_2019 = df[df['User Name'] == 'farmrio'].query('`Post Created Date` >= "2019-01-01" and `Post Created Date` <= "2019-12-31"')
df_farmrio_2019_interactions = df_farmrio_2019.groupby('Post Created Date')['Total Interactions'].sum().reset_index()
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_farmrio_2019_interactions, x='Post Created Date', y='Total Interactions').set(title='Total de interações por dia 2019 - farmrio')
# Out:
# [Text(0.5, 1.0, 'Total de interações por dia 2019 - farmrio')]

# %%
df_farmrio_2020 = df[df['User Name'] == 'farmrio'].query('`Post Created Date` >= "2020-01-01" and `Post Created Date` <= "2020-12-31"')
df_farmrio_2020_interactions = df_farmrio_2020.groupby('Post Created Date')['Total Interactions'].sum().reset_index()
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_farmrio_2020_interactions, x='Post Created Date', y='Total Interactions').set(title='Total de interações por dia 2020 - farmrio')
# Out:
# [Text(0.5, 1.0, 'Total de interações por dia 2020 - farmrio')]

# %%
df_farmrio_2021 = df[df['User Name'] == 'farmrio'].query('`Post Created Date` >= "2021-01-01" and `Post Created Date` <= "2021-12-31"')
df_farmrio_2021_interactions = df_farmrio_2021.groupby('Post Created Date')['Total Interactions'].sum().reset_index()
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_farmrio_2021_interactions, x='Post Created Date', y='Total Interactions').set(title='Total de interações por dia 2021 - farmrio')
# Out:
# [Text(0.5, 1.0, 'Total de interações por dia 2021 - farmrio')]

# %%
df_farmrio_2022 = df[df['User Name'] == 'farmrio'].query('`Post Created Date` >= "2022-01-01" and `Post Created Date` <= "2022-12-31"')
df_farmrio_2022_interactions = df_farmrio_2022.groupby('Post Created Date')['Total Interactions'].sum().reset_index()
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_farmrio_2022_interactions, x='Post Created Date', y='Total Interactions').set(title='Total de interações por dia 2022 - farmrio')
# Out:
# [Text(0.5, 1.0, 'Total de interações por dia 2022 - farmrio')]
